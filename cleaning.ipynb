# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./yoda-corpus.csv", encoding = "latin1")

# %%
data
# Out:
#      movie  scene  line   character  \
# 0        1    129  1158    narrator
# 1        1    129  1159     QUI-GON
# 2        1    129  1160  MACE WINDU
# 3        1    129  1161      KI-ADI
# 4        1    129  1162        YODA
# ..     ...    ...   ...         ...
# 366      6     48   373        LUKE
# 367      6     48   374        YODA
# 368      6     48   375    narrator
# 369      6     48   376        YODA
# 370      6     48   377    narrator
#
#                                                   text  \
# 0    QUI-GON stands in a tall stately room. Twelve ...
# 1    ...my only conclusion can be that it was a Sit...
# 2                                       A Sith Lord?!?
# 3    Impossible! The Sith have been extinct for a m...
# 4    The very Republic is threatened, if involved t...
# ..                                                 ...
# 366                                   Well, I'm sorry.
# 367  Remember, a Jedi's strength flows from the For...
# ...

# %%
data.drop(["slug", "component", "line", "scene"], axis="columns", inplace=True)

# %%
data
# Out:
#      movie   character                                               text
# 0        1    narrator  QUI-GON stands in a tall stately room. Twelve ...
# 1        1     QUI-GON  ...my only conclusion can be that it was a Sit...
# 2        1  MACE WINDU                                     A Sith Lord?!?
# 3        1      KI-ADI  Impossible! The Sith have been extinct for a m...
# 4        1        YODA  The very Republic is threatened, if involved t...
# ..     ...         ...                                                ...
# 366      6        LUKE                                   Well, I'm sorry.
# 367      6        YODA  Remember, a Jedi's strength flows from the For...
# 368      6    narrator  fear, aggression. The dark side are they.  Onc...
# 369      6        YODA  Luke...Luke...Do not...Do not underestimate th...
# 370      6    narrator  or suffer your father's fate, you will. Luke, ...
#
# [371 rows x 3 columns]

# %%
data.to_csv("yoda.csv")
